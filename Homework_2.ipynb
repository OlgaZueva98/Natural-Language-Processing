# %%
# !pip install textdistance
# Out:
# Collecting textdistance
#   Downloading https://files.pythonhosted.org/packages/90/19/0ec54a05e269537341b489da4e8a7b86e34b94e0096f67ecfcbab98cd3aa/textdistance-4.1.3-py3-none-any.whl
# Installing collected packages: textdistance
# Successfully installed textdistance-4.1.3
# You are using pip version 10.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
import textdistance
from collections import Counter
from string import punctuation
punct = set(punctuation)
import re

# %%
corpus = [sent.split() for sent in open(r'D:\corpus_ng.txt', encoding='utf-8').read().splitlines()]
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

# %%
vocab = list(WORDS.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
def get_closest_hybrid_match(text, X, vec, TOPN=3, metric=textdistance.levenshtein):
    v = vec.transform([text])
    similarities = cosine_distances(v, X)
    topn = similarities.argsort()[0][:TOPN]
    close_words = [id2word[top] for top in topn]
    sim = Counter()
    for word in close_words:
        sim[word] = metric.normalized_similarity(text, word)
    closest = sim.most_common(1)[0]
    
    return closest

# %%
get_closest_hybrid_match('опофеоз', X, vec, TOPN=3, metric=textdistance.levenshtein)
# Out:
# ('апофеоз', 0.8571428571428572)

# %%
correct = open(r'D:\correct_sents.txt', 'r', encoding = 'utf-8').read().splitlines()
incorrect = open(r'D:\sents_with_mistakes.txt', 'r', encoding = 'utf-8').read().splitlines()

# %%
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_1 if (set(token)-punct)]
    tokens_2 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_2 if (set(token)-punct)]
    
    return list(zip(tokens_1, tokens_2))

# %%
mistakes = []

for i in range(len(correct)):
    
    word_pairs = align_words(correct[i], incorrect[i])
    
    for pair in word_pairs:
        if pair[0] != pair[1]:
            mistakes.append(pair[1])

# %%
mistakes[:5]
# Out:
# ['симпатичнейшое', 'опофеозом', 'пояним', 'полчатся', 'оччччень']

# %%
true = []
for word in mistakes:
    cor_word = get_closest_hybrid_match(word, X, vec, TOPN=3, metric=textdistance.levenshtein)
    true.append(cor_word)

# %%
true
# Out:
# [('пластичнейшими', 0.4285714285714286),
#  ('апофеозом', 0.8888888888888888),
#  ('поясним', 0.8571428571428572),
#  ('ополчатся', 0.8888888888888888),
#  ('чечни', 0.375),
#  ('защищено', 0.375),
#  ('отсутствие', 0.9),
#  ('основная', 0.875),
#  ('роснано', 0.2857142857142857),
#  ('общем', 0.8333333333333334),
#  ('как', 1.0),
#  ('вы', 1.0),
#  ('знаете', 1.0),
#  ('из', 1.0),
#  ('моего', 1.0),
#  ('не', 1.0),
#  ('давнего', 1.0),
#  ('ящика', 0.8),
#  ('предлагаю', 0.8888888888888888),
#  ('сегодняшнее', 0.9090909090909091),
#  ('хорошее', 0.8571428571428572),
#  ('выходных', 0.875),
#  ('трампу', 0.33333333333333337),
#  ('штат', 0.75),
#  ('лучше', 0.8),
#  ('аффектов', 0.33333333333333337),
#  ('компьютерная', 0.9166666666666666),
#  ('ссоре', 0.8),
#  ('что', 0.6),
#  ('машинный', 0.625),
#  ('хорошее', 0.8571428571428572),
#  ('молодежи', 0.875),
#  ('участвовать', 0.9166666666666666),
#  ('сиднея', 0.6666666666666667),
#  ('вешать', 1.0),
#  ('ответственность', 0.9333333333333333),
#  ('это', 0.6666666666666667),
#  ('канаш', 0.5714285714285714),
#  ('начального', 0.8),
#  ('зажег', 0.8),
#  ('взрослому', 0.8181818181818181),
#  ('предыдущую', 0.9),
#  ('поддерживаться', 0.7142857142857143),
#  ('шпионаж', 0.1428571428571429),
#  ('конкретика', 0.4),
#  ('миллиона', 0.4),
#  ('молодежи', 0.875),
#  ('нарушающие', 0.4),
#  ('монологом', 0.7272727272727273),
#  ('молчанию', 0.625),
#  ('турбъерн', 0.5),
#  ('комментариев', 0.9166666666666666),
#  ('ответственный', 0.9230769230769231),
#  ('отличный', 0.875),
#  ('рассчитаны', 0.9),
#  ('объединились', 0.5833333333333333),
#  ('веселились', 0.9090909090909091),
#  ('спрашивая', 0.8181818181818181),
#  ('возбудитель', 0.4),
#  ('ка', 0.33333333333333337),
#  ('хочется', 0.875),
#  ('писанием', 0.375),
#  ('супермаркете', 0.9230769230769231),
#  ('серебряные', 0.9090909090909091),
#  ('расформировать', 0.6428571428571428),
#  ('самой', 0.7142857142857143),
#  ('тула', 0.75),
#  ('ваще', 1.0),
#  ('тока', 1.0),
#  ('наверно', 0.875),
#  ('очень', 0.7142857142857143),
#  ('каток', 0.6),
#  ('ущи', 0.4285714285714286),
#  ('канда', 0.5),
#  ('очное', 0.375),
#  ('симпатическая', 0.9230769230769231),
#  ('результаты', 0.9),
#  ('прошептав', 0.4545454545454546),
#  ('препараты', 0.7777777777777778),
#  ('съездил', 0.75),
#  ('расчете', 0.875),
#  ('странно', 0.8571428571428572),
#  ('вообще', 0.8333333333333334),
#  ('пришлись', 0.875),
#  ('приветствуется', 0.9333333333333333),
#  ('опасался', 0.75),
#  ('сражался', 0.625),
#  ('однажды', 0.875),
#  ('неразумные', 0.5),
#  ('поцеловать', 0.4545454545454546),
#  ('сочувствующие', 0.9230769230769231),
#  ('трафике', 0.375),
#  ('силин', 0.4),
#  ('естественно', 0.9166666666666666),
#  ('слишком', 0.8571428571428572),
#  ('доминант', 0.375),
#  ('основные', 0.8888888888888888),
#  ('получаться', 0.9090909090909091),
#  ('разрушаться', 0.9166666666666666),
#  ('координирует', 0.9230769230769231),
#  ('движение', 0.8888888888888888),
#  ('правила', 1.0),
#  ('текста', 0.33333333333333337),
#  ('рассказчик', 0.9),
#  ('приехали', 0.875),
#  ('прочитал', 0.8888888888888888),
#  ('намного', 0.8571428571428572),
#  ('открываю', 0.75),
#  ('написанное', 0.9),
#  ('выписывает', 0.4),
#  ('пересказывать', 0.9285714285714286),
#  ('пятый', 0.8),
#  ('текста', 0.33333333333333337),
#  ('что', 0.6),
#  ('соборности', 0.5),
#  ('священнослужители', 0.9411764705882353),
#  ('неосознанно', 0.8461538461538461),
#  ('сохраняю', 0.75),
#  ('ваще', 1.0),
#  ('трата', 0.4),
#  ('по-прежнему', 0.9090909090909091),
#  ('первой', 0.8333333333333334),
#  ('канда', 0.5),
#  ('текста', 0.33333333333333337),
#  ('пежо', 0.4),
#  ('когда', 0.7142857142857143),
#  ('отдала', 0.8571428571428572),
#  ('ваще', 1.0),
#  ('фес', 0.33333333333333337),
#  ('вообще', 0.8333333333333334),
#  ('препараты', 0.8888888888888888),
#  ('нищета', 0.6666666666666667),
#  ('гулиева', 0.75),
#  ('самыми', 0.8333333333333334),
#  ('веси', 0.4),
#  ('но', 1.0),
#  ('кое-как', 0.7142857142857143),
#  ('старым', 0.625),
#  ('рекомендация', 0.9230769230769231),
#  ('напроектировали', 0.9333333333333333),
#  ('адмиралъ', 0.25),
#  ('одноклассниках', 0.9285714285714286),
#  ('ромэн', 0.5),
#  ('ваще', 1.0),
#  ('шерше', 0.6),
#  ('фальковича', 0.4),
#  ('речка', 0.16666666666666663),
#  ('температура', 0.9090909090909091),
#  ('качество', 0.8),
#  ('симптомы', 0.875),
#  ('потому', 0.8333333333333334),
#  ('заверьте', 0.375),
#  ('прощалось', 0.7777777777777778),
#  ('речка', 0.16666666666666663),
#  ('прикольные', 0.9),
#  ('одноклассников', 0.9285714285714286),
#  ('соборности', 0.5),
#  ('хочется', 0.875),
#  ('посмотреть', 0.8),
#  ('хочется', 0.875),
#  ('профессор', 0.8888888888888888),
#  ('прикольные', 0.9090909090909091),
#  ('начинать', 0.625),
#  ('выбегает', 0.5454545454545454),
#  ('ее', 1.0),
#  ('из', 1.0),
#  ('под', 1.0),
#  ('былое', 0.5),
#  ('никогда', 1.0),
#  ('любви', 1.0),
#  ('то', 1.0),
#  ('мужиков', 0.8571428571428572),
#  ('сегодняшние', 0.9090909090909091),
#  ('поскольку', 0.8888888888888888),
#  ('компьютерные', 0.9166666666666666),
#  ('начального', 0.8),
#  ('рассмотрим', 0.9),
#  ('византии', 0.5),
#  ('потеряна', 0.75),
#  ('навредишь', 0.4444444444444444),
#  ('осмысляющие', 0.5454545454545454),
#  ('убрать', 0.8333333333333334),
#  ('процедура', 0.8181818181818181),
#  ('коммунисты', 0.9090909090909091),
#  ('сиднея', 0.6666666666666667),
#  ('ответственно', 0.9166666666666666),
#  ('очное', 0.375),
#  ('получаться', 0.9090909090909091),
#  ('монтаж', 0.5),
#  ('семеро', 0.5),
#  ('рисунок', 0.7142857142857143),
#  ('летчикам', 0.375),
#  ('продолжения', 1.0),
#  ('потону', 0.8333333333333334),
#  ('спасибо', 0.7142857142857143),
#  ('монтаж', 0.5),
#  ('отставать', 0.4444444444444444),
#  ('следующий', 0.8888888888888888),
#  ('основанный', 0.7),
#  ('очень', 0.8333333333333334),
#  ('вообще', 0.8333333333333334),
#  ('фес', 0.33333333333333337),
#  ('ошибочно', 0.875),
#  ('сиднея', 0.6666666666666667),
#  ('страшна', 0.6),
#  ('равняться', 0.7777777777777778),
#  ('канаш', 0.5714285714285714),
#  ('компания', 0.75),
#  ('разгоне', 0.4285714285714286),
#  ('тристецца', 0.5),
#  ('сажусь', 0.8333333333333334),
#  ('древнейшую', 0.19999999999999996),
#  ('электронная', 0.9090909090909091),
#  ('ваще', 1.0),
#  ('организмы', 0.7777777777777778),
#  ('обучено', 0.8571428571428572),
#  ('долго', 0.7142857142857143),
#  ('садится', 1.0),
#  ('серебряному', 0.8181818181818181),
#  ('периодически', 0.9166666666666666),
#  ('сиднея', 0.6666666666666667),
#  ('по-любому', 0.8888888888888888),
#  ('шерше', 0.6),
#  ('реклама', 0.8571428571428572),
#  ('безупречно', 0.8333333333333334),
#  ('ищите', 1.0),
#  ('какова', 1.0),
#  ('арена', 0.6),
#  ('сначала', 0.8571428571428572),
#  ('продолжительность', 0.8823529411764706),
#  ('небольшая', 0.8888888888888888),
#  ('симпатичный', 0.9090909090909091),
#  ('всякой', 0.8333333333333334),
#  ('довольно', 0.875),
#  ('оглушал', 0.4285714285714286),
#  ('открыл', 0.8571428571428572),
#  ('подняла', 0.5),
#  ('подробный', 0.8888888888888888),
#  ('обдумываю', 0.8888888888888888),
#  ('вечером', 0.8571428571428572),
#  ('отечественные', 0.8461538461538461),
#  ('простыня', 0.5),
#  ('спецназовцам', 0.33333333333333337),
#  ('монастырь', 0.9),
#  ('большое', 1.0),
#  ('текста', 0.33333333333333337),
#  ('знаю', 0.6666666666666667),
#  ('ходить', 1.0),
#  ('анан', 0.5),
#  ('море', 1.0),
#  ('делать', 1.0),
#  ('ремонт', 1.0),
#  ('кого', 1.0),
#  ('будь', 0.6666666666666667),
#  ('периодически', 0.9166666666666666),
#  ('вообще', 0.8333333333333334),
#  ('осуществленный', 0.6428571428571428),
#  ('чуть', 0.75),
#  ('естественно', 0.9166666666666666),
#  ('естественно', 0.9166666666666666),
#  ('пойдете', 0.625),
#  ('тока', 1.0),
#  ('обычным', 0.8571428571428572),
#  ('естественно', 0.9166666666666666),
#  ('естественно', 0.9166666666666666),
#  ('спасибо', 0.875),
#  ('начального', 0.8),
#  ('поднимать', 0.8888888888888888),
#  ('отмечать', 0.4),
#  ('предположительно', 0.9375),
#  ('неожиданный', 0.9090909090909091),
#  ('галичем', 0.5),
#  ('хорошее', 0.7142857142857143),
#  ('потомку', 0.7142857142857143),
#  ('работодатели', 0.9166666666666666),
#  ('присоединилась', 0.7857142857142857),
#  ('ето', 1.0),
#  ('сиднея', 0.6666666666666667),
#  ('окончилась', 0.30000000000000004),
#  ('очень', 0.6),
#  ('текста', 0.33333333333333337),
#  ('обновиться', 0.5),
#  ('парламентский', 0.9285714285714286),
#  ('привезла', 0.875),
#  ('потребовавшееся', 0.33333333333333337),
#  ('соберутся', 0.8888888888888888),
#  ('некоторым', 0.8888888888888888),
#  ('прямо', 0.8),
#  ('следующий', 0.8888888888888888),
#  ('сиднея', 0.6666666666666667),
#  ('шиле', 0.4),
#  ('старайтесь', 0.7272727272727273),
#  ('поводыря', 0.5),
#  ('ушедшего', 0.7272727272727273),
#  ('извините', 0.875),
#  ('чувствовалась', 0.9230769230769231),
#  ('гордится', 1.0),
#  ('поссорились', 0.8181818181818181),
#  ('накормить', 0.5555555555555556),
#  ('сначала', 0.8571428571428572),
#  ('рюкзак', 0.8571428571428572),
#  ('декаде', 0.5),
#  ('ваще', 1.0),
#  ('официальные', 0.8181818181818181),
#  ('займа', 0.5714285714285714),
#  ('любое', 0.8333333333333334),
#  ('пути', 0.8),
#  ('надуманная', 0.75),
#  ('история', 0.7142857142857143),
#  ('предсказывают', 0.7692307692307692),
#  ('погрузился', 0.8333333333333334),
#  ('основная', 0.8888888888888888),
#  ('набрала', 0.875),
#  ('девчонки', 0.875),
#  ('зажали', 0.6666666666666667),
#  ('невозможно', 0.7692307692307692),
#  ('пишите', 0.8571428571428572),
#  ('неоднозначное', 0.9230769230769231),
#  ('внутренний', 0.9),
#  ('строятся', 0.8888888888888888),
#  ('дананг', 0.375),
#  ('расчет', 0.8571428571428572),
#  ('потому', 0.8571428571428572),
#  ('эмоциональная', 0.8461538461538461),
#  ('компанией', 0.6428571428571428),
#  ('буше', 0.6),
#  ('мощение', 0.5714285714285714),
#  ('вообще', 0.8333333333333334),
#  ('естественно', 0.9166666666666666),
#  ('интереснейшее', 0.7333333333333334),
#  ('долго', 0.7142857142857143),
#  ('благодаря', 0.8888888888888888),
#  ('довольно', 0.875),
#  ('мя', 1.0),
#  ('следующие', 0.8888888888888888),
#  ('приспособление', 0.9285714285714286),
#  ('очное', 0.375),
#  ('сиднея', 0.6666666666666667),
#  ('некоторые', 0.8888888888888888),
#  ('шт', 0.6666666666666667),
#  ('оставалось', 0.9),
#  ('страусы', 0.875),
#  ('смешные', 0.8571428571428572),
#  ('одноклассница', 0.8461538461538461),
#  ('естественно', 0.9166666666666666),
#  ('замок', 0.4),
#  ('сначала', 0.8571428571428572),
#  ('сносное', 0.4285714285714286),
#  ('фраз', 0.2857142857142857),
#  ('совершенно', 0.9),
#  ('текста', 0.33333333333333337),
#  ('получаться', 0.9090909090909091),
#  ('предаться', 0.7777777777777778),
#  ('позавчера', 0.9),
#  ('наконец', 0.7777777777777778),
#  ('кручение', 0.625),
#  ('прокачки', 0.625),
#  ('прикладным', 0.7272727272727273),
#  ('следите', 0.875),
#  ('пассажирам', 0.9),
#  ('территорию', 0.8),
#  ('любопытства', 0.9090909090909091),
#  ('диоген', 0.33333333333333337),
#  ('отдаться', 0.8888888888888888),
#  ('замечательные', 0.9230769230769231),
#  ('нищета', 0.6666666666666667),
#  ('родные', 0.75),
#  ('нобелиат', 0.4545454545454546),
#  ('шерше', 0.6),
#  ('чеховой', 0.5555555555555556),
#  ('официально', 0.9090909090909091),
#  ('хорошее', 0.8571428571428572),
#  ('очень', 0.7142857142857143),
#  ('прагматичного', 0.7692307692307692),
#  ('вообще', 0.8333333333333334),
#  ('общаются', 0.8888888888888888),
#  ('соединение', 0.7),
#  ('общем', 0.8333333333333334),
#  ('ницца', 0.6666666666666667),
#  ('мне', 1.0),
#  ('что', 1.0),
#  ('я', 1.0),
#  ('нашел', 1.0),
#  ('таки', 1.0),
#  ('практически', 0.9166666666666666),
#  ('естественно', 0.9166666666666666),
#  ('сворачивал', 0.6),
#  ('пять', 0.8),
#  ('ана', 1.0),
#  ('сегодня', 0.8571428571428572),
#  ('общительность', 0.3076923076923077),
#  ('каток', 0.6),
#  ('очное', 0.375),
#  ('холодная', 0.8),
#  ('снеготаяния', 0.36363636363636365),
#  ('ваще', 1.0),
#  ('долго-долго', 0.4782608695652174),
#  ('нищета', 0.6666666666666667),
#  ('сносное', 0.4285714285714286),
#  ('экскурсовода', 0.8333333333333334),
#  ('зачет', 0.8333333333333334),
#  ('будто', 0.4285714285714286),
#  ('покажут', 0.875),
#  ('коне', 0.5),
#  ('далек', 0.19999999999999996),
#  ('колады', 0.5),
#  ('подскажет', 0.8),
#  ('кровища', 0.75),
#  ('предлагаю', 0.9),
#  ('равняться', 0.7777777777777778),
#  ('покопаться', 0.9),
#  ('очень', 0.7142857142857143),
#  ('сентябрьский', 0.9166666666666666),
#  ('целую', 0.8),
#  ('рекомендую', 0.8333333333333334),
#  ('промозглом', 0.8),
#  ('вообще', 0.8571428571428572),
#  ('то', 1.0),
#  ('распределить', 0.8333333333333334),
#  ('текста', 0.33333333333333337),
#  ('собственно', 0.9),
#  ('одноклассники', 0.9230769230769231),
#  ('подашься', 0.25),
#  ('обожаю', 0.8333333333333334),
#  ('смущенного', 0.6),
#  ('третирование', 0.6875),
#  ('что', 1.0),
#  ('бы', 1.0),
#  ('больно', 1.0),
#  ('былое', 0.5),
#  ('царь', 0.33333333333333337),
#  ('хорошее', 0.8571428571428572),
#  ('провинция', 0.7777777777777778),
#  ('скульптура', 0.9),
#  ('разгадать', 0.8888888888888888),
#  ('хочется', 0.875),
#  ('обязательное', 0.8333333333333334),
#  ('разделить', 0.6666666666666667),
#  ('стоявший', 0.6666666666666667),
#  ('ето', 1.0),
#  ('одно', 1.0),
#  ('вшей', 0.8),
#  ('кобаяши', 0.4285714285714286),
#  ('очное', 0.375),
#  ('цика', 0.4),
#  ('коршунов', 0.5555555555555556),
#  ('способность', 0.9166666666666666),
#  ('несколько', 0.9),
#  ('территория', 0.9),
#  ('одноклассники', 0.9230769230769231),
#  ('максимовича', 0.2941176470588235),
#  ('днесь', 0.6),
#  ('нравиться', 1.0),
#  ('программа', 0.8888888888888888),
#  ('управляется', 0.36363636363636365),
#  ('извините', 0.875),
#  ('выразился', 0.8888888888888888),
#  ('напомнило', 0.9),
#  ('старый', 0.75),
#  ('пройдя', 0.8333333333333334),
#  ('ирказе', 0.5),
#  ('ето', 1.0),
#  ('проколе', 0.7142857142857143),
#  ('воробьевых', 0.4),
#  ('вальехо', 0.4285714285714286),
#  ('получаться', 0.9090909090909091),
#  ('получаться', 0.9090909090909091),
#  ('ни', 1.0),
#  ('половозрелый', 0.8333333333333334),
#  ('естественно', 0.9166666666666666),
#  ('кабы', 0.8),
#  ('из', 1.0),
#  ('под', 1.0),
#  ('очень', 0.7142857142857143),
#  ('вообще', 0.8333333333333334),
#  ('звонят', 0.33333333333333337),
#  ('ето', 1.0),
#  ('ето', 1.0),
#  ('обычные', 0.8571428571428572),
#  ('эндокринные', 0.2727272727272727),
#  ('рассчитан', 0.8888888888888888),
#  ('люблю', 0.8),
#  ('попалась', 0.5),
#  ('очнись', 0.6666666666666667),
#  ('потратить', 0.9),
#  ('расчетов', 0.8888888888888888),
#  ('каток', 0.6),
#  ('ваще', 1.0),
#  ('бомбежку', 0.75),
#  ('реальные', 0.875),
#  ('жемчужин', 0.7),
#  ('перестает', 0.4444444444444444),
#  ('пройдя', 0.8333333333333334),
#  ('сколько', 0.7142857142857143),
#  ('острое', 1.0),
#  ('айленд', 0.625),
#  ('семантическая', 0.9230769230769231),
#  ('превратиться', 0.8571428571428572),
#  ('все-таки', 0.75),
#  ('днесь', 0.6),
#  ('наконец', 0.7777777777777778),
#  ('наконец', 0.7777777777777778),
#  ('часть', 0.8),
#  ('че', 1.0),
#  ('ето', 1.0),
#  ('вообще', 0.8333333333333334),
#  ('шестью', 0.1428571428571429),
#  ('обожженных', 0.6363636363636364),
#  ('опрошенных', 0.5),
#  ('пытаюсь', 0.875),
#  ('запретную', 0.5555555555555556),
#  ('простите', 0.8888888888888888),
#  ('начали', 0.8571428571428572),
#  ('хочется', 0.875),
#  ('текста', 0.33333333333333337),
#  ('потеплением', 0.6363636363636364),
#  ('сказала', 0.8571428571428572),
#  ('сочетание', 0.8888888888888888),
#  ('родителям', 0.8888888888888888),
#  ('вообще', 0.8333333333333334),
#  ('спасибо', 0.7142857142857143),
#  ('сиднея', 0.6666666666666667),
#  ('приятно', 0.8571428571428572),
#  ('сосо', 0.75),
#  ('старыми', 0.8571428571428572),
#  ('встречающимися', 0.9285714285714286),
#  ('сенсаций', 0.375),
#  ('довольно', 0.875),
#  ('волошинском', 0.4545454545454546),
#  ('поэтому', 0.7142857142857143),
#  ('понимают', 0.875),
#  ('почты', 0.4),
#  ('насчет', 0.8333333333333334),
#  ('оказывается', 0.9090909090909091),
#  ('пронзительной', 0.7692307692307692),
#  ('хочется', 0.875),
#  ('начального', 0.8),
#  ('прочат', 0.2857142857142857),
#  ('сиднея', 0.6666666666666667),
#  ('чудесный', 0.8888888888888888),
#  ('насыщенные', 0.8),
#  ('предельного', 0.6363636363636364),
#  ('продолжаем', 0.9),
#  ('солнце', 0.6666666666666667),
#  ('тока', 1.0),
#  ('сиднея', 0.6666666666666667),
#  ('прямо', 0.8333333333333334),
#  ('наподобие', 0.8888888888888888),
#  ('огпу', 0.2727272727272727),
#  ('спасибо', 0.8571428571428572),
#  ('предъявит', 0.5),
#  ('модное', 0.5),
#  ('очень', 0.7142857142857143),
#  ('зачет', 0.8333333333333334),
#  ('пришлись', 0.875),
#  ('сиднея', 0.6666666666666667),
#  ('символизирует', 0.9230769230769231),
#  ('очень', 0.8333333333333334),
#  ('остается', 0.875),
#  ('оглядки', 0.2857142857142857),
#  ('периодически', 0.9166666666666666),
#  ('мысе', 0.6666666666666667),
#  ('отдали', 0.5714285714285714),
#  ('следующего', 0.9),
#  ('атомных', 0.1428571428571429),
#  ('вообще', 0.8333333333333334),
#  ('окрашенное', 0.5),
#  ('по-любому', 0.8888888888888888),
#  ('результат', 0.8888888888888888),
#  ('ого', 0.6),
#  ('ваще', 1.0),
#  ('знакомая', 0.6666666666666667),
#  ('девчонка', 0.75),
#  ('погода', 0.8333333333333334),
#  ('декорум', 0.41666666666666663),
#  ('ровно', 1.0),
#  ('остальном', 0.6666666666666667),
#  ('приехал', 0.75),
#  ('периодически', 0.9166666666666666),
#  ('кошачьи', 0.33333333333333337),
#  ('остальное', 0.8888888888888888),
#  ('ничего', 0.8571428571428572),
#  ('искусстве', 0.8888888888888888),
#  ('года', 0.5),
#  ('справедливыми', 0.9285714285714286),
#  ('комплексное', 0.9090909090909091),
#  ('связаться', 0.6666666666666667),
#  ('просмотре', 0.9),
#  ('очень', 0.8333333333333334),
#  ('что', 0.6),
#  ('каток', 0.6),
#  ('заверьте', 0.375),
#  ('получилась', 0.9090909090909091),
#  ('найдутся', 0.8888888888888888),
#  ('экспериментируя', 0.9333333333333333),
#  ('рассматривает', 0.8461538461538461),
#  ('очень', 0.7142857142857143),
#  ('раскрытие', 0.9),
#  ('нашло', 0.6),
#  ('совсем', 0.8571428571428572),
#  ('прежнего', 0.5),
#  ('периодически', 0.9166666666666666),
#  ('впереди', 0.8571428571428572),
#  ('очень', 0.7142857142857143),
#  ('ощущениям', 0.33333333333333337),
#  ('хочется', 0.875),
#  ('гостиничного', 0.5),
#  ('ногам', 0.6),
#  ('продажа', 0.8571428571428572),
#  ('присоединяешься', 0.8),
#  ('учитель', 0.6363636363636364),
#  ('эх', 0.2857142857142857),
#  ('очень', 0.8333333333333334),
#  ('прадо', 0.5),
#  ('айдан', 0.5714285714285714),
#  ('пейзаж', 0.8571428571428572),
#  ('поздравляю', 0.9),
#  ('никогда', 0.875),
#  ('днесь', 0.6),
#  ('смертельную', 0.9166666666666666),
#  ('кадаффи', 0.4285714285714286),
#  ('каток', 0.6),
#  ('отсрочку', 0.875),
#  ('охранники', 0.7777777777777778),
#  ('по-любому', 0.8888888888888888),
#  ('сиднея', 0.6666666666666667),
#  ('осколочное', 0.4),
#  ('следующий', 0.8888888888888888),
#  ('черепахи', 0.875),
#  ('обошел', 0.5),
#  ('нашло', 0.6),
#  ('хочется', 0.875),
#  ('посошком', 0.5),
#  ('ваще', 1.0),
#  ('миллиарды', 0.7777777777777778),
#  ('333', 0.33333333333333337),
#  ('поздравляю', 0.9),
#  ('ето', 1.0),
#  ('пассажир', 0.875),
#  ('опять', 0.8),
#  ('хань', 0.6),
#  ('почему', 0.8333333333333334),
#  ('сундучок', 0.4),
#  ('ужасы', 0.6),
#  ('конце', 0.4285714285714286),
#  ('дирижер', 0.8571428571428572),
#  ('расчет', 0.8571428571428572),
#  ('транспортировка', 0.9333333333333333),
#  ('как', 1.0),
#  ('то', 1.0),
#  ('странно', 1.0),
#  ('анан', 0.5),
#  ('улице', 1.0),
#  ('супер', 1.0),
#  ('просто', 1.0),
#  ('а', 1.0),
#  ('я', 1.0),
#  ('целый', 1.0),
#  ('день', 1.0),
#  ('пропала', 0.875),
#  ('потом', 1.0),
#  ('робкой', 0.5714285714285714),
#  ('занималась', 1.0),
#  ('ну', 1.0),
#  ('общем', 0.8333333333333334),
#  ('низкокалорийной', 0.8125),
#  ('ночи', 0.5),
#  ('удивительно', 0.9090909090909091),
#  ('посмотри', 0.875),
#  ('колоть', 0.16666666666666663),
#  ('закапал', 0.6666666666666667),
#  ('наркотиков', 0.9),
#  ('расчеты', 0.875),
#  ('каток', 0.6),
#  ('поощрить', 0.6153846153846154),
#  ('проверку', 0.875),
#  ('дискутировали', 0.8125),
#  ('портос', 0.6666666666666667),
#  ('люблю', 0.8333333333333334),
#  ('фас', 0.2222222222222222),
#  ('рассчитан', 0.8888888888888888),
#  ('президент', 0.9),
#  ('рассказе', 0.8888888888888888),
#  ('годен', 0.6),
#  ('монтаж', 0.5),
#  ('программу', 0.8888888888888888),
#  ('хочется', 0.875),
#  ('развеивает', 0.6666666666666667),
#  ('говорит', 0.8571428571428572),
#  ('по-любому', 0.8888888888888888),
#  ('любимый', 0.875),
#  ('получилось', 0.9),
#  ('ненаучной', 0.5555555555555556),
#  ('правильная', 0.9),
#  ('пространство', 0.9166666666666666),
#  ('прогуляется', 0.7272727272727273),
#  ('продукты', 0.875),
#  ('наконец', 0.7777777777777778),
#  ('лекарственные', 0.8461538461538461),
#  ('попался', 0.5714285714285714),
#  ('левостороннее', 0.9230769230769231),
#  ('из', 0.5),
#  ('днесь', 0.6),
#  ('расистская', 0.7),
#  ('напротив', 0.8888888888888888),
#  ('разгула', 0.4),
#  ('текста', 0.33333333333333337),
#  ('называем', 0.6666666666666667),
#  ('снесет', 0.375),
#  ('коридоры', 0.8888888888888888),
#  ('раннее', 1.0),
#  ('стоп', 0.5),
#  ('обратно', 0.8571428571428572),
#  ('что', 0.6),
#  ('царицыно', 0.375),
#  ('ночи', 0.5),
#  ('эксперты', 0.875),
#  ('хочется', 0.875),
#  ('методологическом', 0.875),
#  ('кокса', 0.6),
#  ('сиднея', 0.6666666666666667),
#  ('девчонки', 0.875),
#  ('приземлилась', 0.8333333333333334),
#  ('цао', 0.33333333333333337),
#  ('неудачи', 0.7),
#  ('надеюсь', 0.8571428571428572),
#  ('спать', 0.8333333333333334),
#  ('симпатичный', 0.9090909090909091),
#  ('погуляет', 0.7777777777777778),
#  ('обязательно', 0.9166666666666666),
#  ('пофантазировал', 0.3571428571428571),
#  ('тусовка', 0.875),
#  ('открыла', 0.7142857142857143),
#  ('бесконечны', 0.4),
#  ('четвертая', 0.8888888888888888),
#  ('остановились', 0.8333333333333334),
#  ('потому', 0.8333333333333334),
#  ('некоторые', 0.8888888888888888),
#  ('овос', 0.5),
#  ('пожалуйста', 0.9),
#  ('монтаж', 0.5),
#  ('может', 0.8),
#  ('очередная', 0.7),
#  ('рассчитаны', 0.9),
#  ('оттуда', 0.8333333333333334),
#  ('недавно', 0.8571428571428572),
#  ('токто', 0.6),
#  ('связанность', 0.8333333333333334),
#  ('оглядки', 0.2857142857142857),
#  ('промывали', 0.2857142857142857),
#  ('издается', 0.625),
#  ('снесет', 0.375),
#  ('приятного', 0.8888888888888888),
#  ('комендант', 0.9),
#  ('текста', 0.33333333333333337),
#  ('хабенским', 0.5555555555555556),
#  ('продавцы', 0.875),
#  ('акции', 0.6),
#  ('дергаться', 0.4444444444444444),
#  ('патологическими', 0.8),
#  ('пожалуйста', 0.7),
#  ('познакомились', 0.9230769230769231),
#  ('представить', 0.8461538461538461),
#  ('попадались', 0.9),
#  ('разделились', 0.2727272727272727),
#  ('разделенной', 0.8333333333333334),
#  ('струю', 1.0),
#  ('намного', 0.8571428571428572),
#  ('котельного', 0.5),
#  ('помогает', 0.875),
#  ('шт', 0.6666666666666667),
#  ('искушением', 0.7),
#  ('хочется', 0.875),
#  ('ночи', 0.5),
#  ('пятница', 0.875),
#  ('из', 0.5),
#  ('44', 0.19999999999999996),
#  ('444', 0.19999999999999996),
#  ('присесть', 0.5),
#  ('оказаться', 0.8),
#  ('сиднея', 0.6666666666666667),
#  ('подойти', 0.7777777777777778),
#  ('поселения', 0.8888888888888888),
#  ('террористический', 0.9375),
#  ('естественно', 0.9166666666666666),
#  ('профессиональные', 0.9411764705882353),
#  ('какая', 0.8),
#  ('стартапу', 0.8888888888888888),
#  ('соответственно', 0.9285714285714286),
#  ('катастрофически', 0.9333333333333333),
#  ('шт', 0.6666666666666667),
#  ('причислялся', 0.7272727272727273),
#  ('направлению', 0.8181818181818181),
#  ('приходиться', 1.0),
#  ('считаешь', 0.25),
#  ('мелодраме', 0.8),
#  ('вообще', 0.8333333333333334),
#  ('наконец', 0.7777777777777778),
#  ('журналисты', 0.9),
#  ('некоторые', 0.8888888888888888),
#  ('осколочное', 0.4),
#  ('фраз', 0.33333333333333337),
#  ('одноклассники', 0.9230769230769231),
#  ('неожиданно', 0.9),
#  ('молодежи', 0.875),
#  ('что', 0.6),
#  ('вообще', 0.8333333333333334),
#  ('сходили', 0.875),
#  ('произошли', 0.8888888888888888),
#  ('хочется', 0.875),
#  ('сиднея', 0.6666666666666667),
#  ('сиднея', 0.6666666666666667),
#  ('че', 1.0),
#  ('отворотов', 0.4444444444444444),
#  ('текста', 0.33333333333333337),
#  ('44', 0.5),
#  ('фаланги', 0.8571428571428572),
#  ('смотрятся', 0.9),
#  ('удалить', 0.875),
#  ('опустил', 0.6666666666666667),
#  ('из', 0.5),
#  ('лучшее', 0.6666666666666667),
#  ('сердце', 0.8333333333333334),
#  ('требование', 0.5454545454545454),
#  ('одна', 0.8),
#  ('вбили', 0.4),
#  ('обожаю', 0.8333333333333334),
#  ('кривляется', 0.9),
#  ('парилку', 0.7142857142857143),
#  ('хочется', 0.875),
#  ('разделить', 0.6666666666666667),
#  ('самодостаточной', 0.7777777777777778),
#  ('заверьте', 0.375),
#  ('последней', 0.8888888888888888),
#  ('текста', 0.33333333333333337),
#  ('транспортная', 0.9166666666666666),
#  ('запланирована', 0.5384615384615384),
#  ('продолжение', 0.9090909090909091),
#  ('что', 0.75),
#  ('что', 0.6),
#  ('у', 1.0),
#  ('очень', 0.7142857142857143),
#  ('ненавижу', 0.875),
#  ('безысходности', 0.8461538461538461),
#  ('нельзя', 0.8571428571428572),
#  ('осколочное', 0.4),
#  ('сиднея', 0.6666666666666667),
#  ('сиднея', 0.6666666666666667),
#  ('позитив', 0.8571428571428572),
#  ('террористы', 0.9),
#  ('очное', 0.375),
#  ('обтереть', 0.875),
#  ('претендент', 0.9),
#  ('осколочное', 0.4),
#  ('приоткрыл', 0.33333333333333337),
#  ('обнялись', 0.375),
#  ('очень', 0.7142857142857143),
#  ('создавалась', 0.9090909090909091),
#  ('сиднея', 0.6666666666666667),
#  ('азербайджан', 0.8181818181818181),
#  ('приоритетно', 0.5454545454545454),
#  ('восхитительной', 0.8571428571428572),
#  ('ваще', 1.0),
#  ('поскользнуться', 0.7857142857142857),
#  ('кисти', 0.5),
#  ('девчонки', 0.875),
#  ('соборности', 0.5),
#  ('посмотрела', 0.9090909090909091),
#  ('поклонники', 0.9),
#  ('самый', 0.7142857142857143),
#  ('очень-то', 0.46153846153846156),
#  ('предаться', 0.7777777777777778),
#  ('чертово', 0.7142857142857143),
#  ('антагонистическое', 0.5882352941176471),
#  ('таскала', 0.6),
#  ('краткая', 0.4285714285714286),
#  ('пишется', 0.875),
#  ('приметы', 0.8571428571428572),
#  ('текста', 0.33333333333333337),
#  ('съемочной', 0.9),
#  ('зарегистрироваться', 0.9444444444444444),
#  ('напрашиваются', 0.9285714285714286),
#  ('соборности', 0.5),
#  ('очень', 0.7142857142857143),
#  ('продолжение', 0.9090909090909091),
#  ('шуршать', 0.2857142857142857),
#  ('может', 0.8333333333333334),
#  ('способа', 0.5714285714285714),
#  ('соответственно', 0.9285714285714286),
#  ('вообще', 0.8333333333333334),
#  ('маршрут', 0.7142857142857143),
#  ('ваще', 0.8),
#  ('пропаганда', 0.30000000000000004),
#  ('неопределенное', 0.9285714285714286),
#  ('продолжено', 0.9090909090909091),
#  ('очень', 0.8),
#  ('перкуссионистка', 0.8),
#  ('одноклассники', 0.9230769230769231),
#  ('почему', 1.0),
#  ('то', 1.0),
#  ('завис', 1.0),
#  ('вообще', 0.8571428571428572),
#  ('вообще', 0.8571428571428572),
#  ('то', 1.0),
#  ('оставила', 0.5),
#  ('расстоянии', 0.9),
#  ('токто', 0.6),
#  ('лучше', 0.8),
#  ('ветвь', 0.8),
#  ('сефти-кар', 0.33333333333333337),
#  ('снесет', 0.375),
#  ('получаться', 0.9090909090909091),
#  ('противоречие', 0.9166666666666666),
#  ('почтовому', 0.33333333333333337),
#  ('просто', 1.0),
#  ('невозможно', 1.0),
#  ('есв', 0.33333333333333337),
#  ('это', 1.0),
#  ('вместить', 0.8888888888888888),
#  ('в', 1.0),
#  ('карточку', 1.0),
#  ('ну', 1.0),
#  ('ни', 1.0),
#  ('как', 1.0),
#  ('каталонии', 0.33333333333333337),
#  ('наверху', 0.8571428571428572),
#  ('пожалеть', 0.875),
#  ('иво', 1.0),
#  ('проявить', 0.875),
#  ('сочувствие', 0.8),
#  ('успокоить', 0.8888888888888888),
#  ('калачева', 0.5),
#  ('сиднея', 0.6666666666666667),
#  ('миньо', 0.6666666666666667),
#  ('ваще', 1.0),
#  ('травиате', 0.625),
#  ('треть', 0.6),
#  ('сначала', 0.8571428571428572),
#  ('фраз', 0.33333333333333337),
#  ('возрастающей', 0.9166666666666666),
#  ('ваще', 1.0),
#  ('насчитал', 0.25),
#  ('предлагаю', 0.8888888888888888),
#  ('мутко', 0.5),
#  ('потомку', 0.7142857142857143),
#  ('организованная', 0.8),
#  ('монтаж', 0.5),
#  ('организм', 0.8888888888888888),
#  ('первый', 0.6666666666666667),
#  ('истцов', 0.30000000000000004),
#  ('наверно', 0.7142857142857143),
#  ('мяч', 0.75),
#  ('сегодня', 0.7777777777777778),
#  ('попытки', 1.0),
#  ('следующий', 0.8888888888888888),
#  ('ответственность', 0.9375),
#  ('чел', 0.5),
#  ('представители', 0.9230769230769231),
#  ('рязань', 0.8571428571428572),
#  ('липовому', 0.3076923076923077),
#  ('чувствую', 0.875),
#  ('учел', 0.5),
#  ('ситроен', 0.33333333333333337),
#  ('щас', 0.6666666666666667),
#  ('может', 0.8),
#  ('ночи', 0.5),
#  ('открылось', 0.5555555555555556),
#  ('акций', 0.6666666666666667),
#  ('миллиардер', 0.9),
#  ('периодически', 0.9166666666666666),
#  ('что', 0.6),
#  ('чувствуется', 0.9166666666666666),
#  ('сиднея', 0.6666666666666667),
#  ('корточках', 0.7777777777777778),
#  ('предлагаю', 0.9),
#  ('следующее', 0.8888888888888888),
#  ('канаш', 0.5714285714285714),
#  ('осколке', 0.625),
#  ('ночи', 0.5),
#  ('анне', 0.75),
#  ('вообще', 0.8333333333333334),
#  ('почувствовала', 0.9230769230769231),
#  ('режиссеру', 0.8888888888888888),
#  ('шт', 0.6666666666666667),
#  ('то', 1.0),
#  ('когда', 0.7142857142857143),
#  ('естественно', 0.9166666666666666),
#  ('удовольствие', 0.9166666666666666),
#  ('привечает', 0.4545454545454546),
#  ('сиднея', 0.6666666666666667),
#  ('из', 0.5),
#  ('придется', 0.8888888888888888),
#  ('очень', 0.7142857142857143),
#  ('ненавижу', 0.875),
#  ('давке', 0.4),
#  ('постараюсь', 0.9),
#  ('приемлемый', 0.9),
#  ('ваще', 1.0),
#  ('сворачивает', 0.2727272727272727),
#  ('сиднея', 0.6666666666666667),
#  ...]
